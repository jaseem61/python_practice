# %%
import numpy as np
import pandas as pd
import csv

# %%
data = pd.read_csv('data.csv',engine = 'python')

# %%
data
# Out:
#          ï»¿      ID                Name  Age  \
# 0          0  158023            L. Messi   31
# 1          1   20801   Cristiano Ronaldo   33
# 2          2  190871           Neymar Jr   26
# 3          3  193080              De Gea   27
# 4          4  192985        K. De Bruyne   27
# ...      ...     ...                 ...  ...
# 18202  18202  238813        J. Lundstram   19
# 18203  18203  243165  N. Christoffersson   19
# 18204  18204  241638           B. Worman   16
# 18205  18205  246268      D. Walker-Rice   17
# 18206  18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
data.Overall.dtype
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# ï»¿                 int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
data.Overall.astype('float')
# Out:
# 0        94.0
# 1        94.0
# 2        92.0
# 3        91.0
# 4        91.0
#          ...
# 18202    47.0
# 18203    47.0
# 18204    47.0
# 18205    47.0
# 18206    46.0
# Name: Overall, Length: 18207, dtype: float64

# %%
data
# Out:
#          ï»¿      ID                Name  Age  \
# 0          0  158023            L. Messi   31
# 1          1   20801   Cristiano Ronaldo   33
# 2          2  190871           Neymar Jr   26
# 3          3  193080              De Gea   27
# 4          4  192985        K. De Bruyne   27
# ...      ...     ...                 ...  ...
# 18202  18202  238813        J. Lundstram   19
# 18203  18203  243165  N. Christoffersson   19
# 18204  18204  241638           B. Worman   16
# 18205  18205  246268      D. Walker-Rice   17
# 18206  18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
data.index.dtype
# Out:
# dtype('int64')

# %%
data.set_index('ï»¿')
# Out:
#            ID                Name  Age  \
# ï»¿
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# ï»¿
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
data.index.dtype
# Out:
# dtype('int64')

# %%
joke=data[pd.isnull(data.Club)].head()

# %%
pd.notnull(data.Club)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18202    True
# 18203    True
# 18204    True
# 18205    True
# 18206    True
# Name: Club, Length: 18207, dtype: bool

# %%
joke=data[pd.isnull(data.Club)].head()

# %%
joke.Club.fillna("wakra",inplace=True)

# %%
joke
# Out:
#      ï»¿      ID          Name  Age  \
# 452  452  207439    L. Paredes   24
# 538  538  156713  A. Granqvist   33
# 568  568  229909      A. Lunev   26
# 677  677  187347  I. Smolnikov   29
# 874  874  187607     A. Dzyuba   29
#
#                                               Photo Nationality  \
# 452  https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 538  https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 568  https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 677  https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 874  https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                     Flag  Overall  Potential   Club  ...  \
# 452  https://cdn.sofifa.org/flags/52.png       80         85  wakra  ...
# 538  https://cdn.sofifa.org/flags/46.png       80         80  wakra  ...
# 568  https://cdn.sofifa.org/flags/40.png       79         81  wakra  ...
# ...

# %%
joke.Club.replace("wakra","doha",inplace=True)

# %%
joke
# Out:
#      ï»¿      ID          Name  Age  \
# 452  452  207439    L. Paredes   24
# 538  538  156713  A. Granqvist   33
# 568  568  229909      A. Lunev   26
# 677  677  187347  I. Smolnikov   29
# 874  874  187607     A. Dzyuba   29
#
#                                               Photo Nationality  \
# 452  https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 538  https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 568  https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 677  https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 874  https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                     Flag  Overall  Potential  Club  ...  \
# 452  https://cdn.sofifa.org/flags/52.png       80         85  doha  ...
# 538  https://cdn.sofifa.org/flags/46.png       80         80  doha  ...
# 568  https://cdn.sofifa.org/flags/40.png       79         81  doha  ...
# ...

# %%
joke.rename(columns={'Name':'Rename'})
# Out:
#      ï»¿      ID        Rename  Age  \
# 452  452  207439    L. Paredes   24
# 538  538  156713  A. Granqvist   33
# 568  568  229909      A. Lunev   26
# 677  677  187347  I. Smolnikov   29
# 874  874  187607     A. Dzyuba   29
#
#                                               Photo Nationality  \
# 452  https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 538  https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 568  https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 677  https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 874  https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                     Flag  Overall  Potential  Club  ...  \
# 452  https://cdn.sofifa.org/flags/52.png       80         85  doha  ...
# 538  https://cdn.sofifa.org/flags/46.png       80         80  doha  ...
# 568  https://cdn.sofifa.org/flags/40.png       79         81  doha  ...
# ...

# %%
joke
# Out:
#      ï»¿      ID          Name  Age  \
# 452  452  207439    L. Paredes   24
# 538  538  156713  A. Granqvist   33
# 568  568  229909      A. Lunev   26
# 677  677  187347  I. Smolnikov   29
# 874  874  187607     A. Dzyuba   29
#
#                                               Photo Nationality  \
# 452  https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 538  https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 568  https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 677  https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 874  https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                     Flag  Overall  Potential  Club  ...  \
# 452  https://cdn.sofifa.org/flags/52.png       80         85  doha  ...
# 538  https://cdn.sofifa.org/flags/46.png       80         80  doha  ...
# 568  https://cdn.sofifa.org/flags/40.png       79         81  doha  ...
# ...

# %%
joke.set_index('ï»¿',inplace=True)

# %%
joke.rename(index={452:1,538:2,568:3,677:4,874:5},inplace=True)

# %%
joke
# Out:
#          ID          Name  Age  \
# ï»¿
# 1    207439    L. Paredes   24
# 2    156713  A. Granqvist   33
# 3    229909      A. Lunev   26
# 4    187347  I. Smolnikov   29
# 5    187607     A. Dzyuba   29
#
#                                               Photo Nationality  \
# ï»¿
# 1    https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 2    https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 3    https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 4    https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 5    https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                     Flag  Overall  Potential  Club  \
# ï»¿
# 1    https://cdn.sofifa.org/flags/52.png       80         85  doha
# 2    https://cdn.sofifa.org/flags/46.png       80         80  doha
# 3    https://cdn.sofifa.org/flags/40.png       79         81  doha
# 4    https://cdn.sofifa.org/flags/40.png       79         79  doha
# ...

# %%
joke.rename_axis("Sl.no",axis='rows',inplace=True)

# %%
joke
# Out:
#            ID          Name  Age  \
# Sl.no
# 1      207439    L. Paredes   24
# 2      156713  A. Granqvist   33
# 3      229909      A. Lunev   26
# 4      187347  I. Smolnikov   29
# 5      187607     A. Dzyuba   29
#
#                                                 Photo Nationality  \
# Sl.no
# 1      https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 2      https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 3      https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 4      https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 5      https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
#                                       Flag  Overall  Potential  Club  \
# Sl.no
# 1      https://cdn.sofifa.org/flags/52.png       80         85  doha
# 2      https://cdn.sofifa.org/flags/46.png       80         80  doha
# 3      https://cdn.sofifa.org/flags/40.png       79         81  doha
# ...

# %%
joke.rename_axis("attributes",axis="columns",inplace=True)

# %%
joke
# Out:
# attributes      ID          Name  Age  \
# Sl.no
# 1           207439    L. Paredes   24
# 2           156713  A. Granqvist   33
# 3           229909      A. Lunev   26
# 4           187347  I. Smolnikov   29
# 5           187607     A. Dzyuba   29
#
# attributes                                           Photo Nationality  \
# Sl.no
# 1           https://cdn.sofifa.org/players/4/19/207439.png   Argentina
# 2           https://cdn.sofifa.org/players/4/19/156713.png      Sweden
# 3           https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 4           https://cdn.sofifa.org/players/4/19/187347.png      Russia
# 5           https://cdn.sofifa.org/players/4/19/187607.png      Russia
#
# attributes                                 Flag  Overall  Potential  Club  \
# Sl.no
# 1           https://cdn.sofifa.org/flags/52.png       80         85  doha
# 2           https://cdn.sofifa.org/flags/46.png       80         80  doha
# ...
